# %% [markdown]
# <h1>주피터 노트북 사용법</h1>
# <ul>
#     <li>코딩모드</li>
#     <li>메모 모드</li>

# %% [markdown]
# # \#은 h1 태그
# ## \##은 h2 태그
# ### \###은 h3 태그

# %% [markdown]
# # ul은 \*로 표시 하위 항목은 들여쓰기 후*
# * 목록
#     * 세부목록1
#     * 세부목록2
#     * 세부목록3

# %% [markdown]
# # 글씨를 굵게 만들기 \*\**내용\*\**
# 글씨를 **굵게** 만들어 보아요.
# # 이탤릭체(기울이기) \**내용\**
# 글씨를 *기울여* 보아요

# %% [markdown]
# # 링크 걸기 \[링크이름\]\(링크 주소\)
# [네이버링크](http://www.naver.com)

# %% [markdown]
# # 이미지 넣기 \!\[이미지 설명\]\(이미지주소\)
# ![그루트](https://pngimg.com/uploads/groot/groot_PNG61.png)

# %% [markdown]
# ![car2.jpg](attachment:car2.jpg)

# %% [markdown]
# # 수식넣기  \\$\\$수식코드\\$\\$
# $${ a^2}$$

# %% [markdown]
# # 표 만들기 \|값|\의미\|기본값\|\|---\|---\|---\|
# |값|의미|기본값|
# |---|:---:|---:|
# |str|문자형 데이터 타입|str|
# |int|정수형 데이터 타임|0|
# |float|실수형 데이터 타입|3.14

# %%
a=10

# %%
1+1
# Out:
# 2

# %%
a
# Out:
# 10
